# %%
import os
from os import listdir

# %%
for x in listdir("/notebooks/yolo/dataset/data/"):
    print(x)
    if ".txt" in x:
        os.rename("/notebooks/yolo/dataset/" + x, "/notebooks/yolo/dataset/labels/" + x)
    else:
        os.rename("/notebooks/yolo/dataset/" + x, "/notebooks/yolo/dataset/images/" + x)
# Out:
# 63.txt
# 72.jpg
# 77.jpg
# 40.txt
# 72.txt
# 126.jpg
# 58.jpg
# 65.txt
# 12.jpg
# 22.txt
# 43.jpg
# 83.txt
# 37.txt
# 65.jpg
# 27.jpg
# 66.jpg
# 52.jpg
# 130.jpg
# 127.txt
# 17.jpg
# 63.jpg
# 12.txt
# 57.jpg
# 6.jpg
# 87.jpg
# 136.jpg
# 115.jpg
# 133.jpg
# 106.txt
# 23.jpg
# 20.jpg
# 91.txt
# 57.txt
# 55.txt
# 69.jpg
# 94.txt
# 48.txt
# 90.txt
# 13.txt
# 9.txt
# 73.txt
# 115.txt
# 132.jpg
# 90.jpg
# 130.txt
# 117.jpg
# 48.jpg
# 32.txt
# 139.txt
# 38.jpg
# 83.jpg
# 112.txt
# 19.jpg
# 111.jpg
# 71.txt
# 101.txt
# 34.txt
# 45.txt
# 11.jpg
# 27.txt
# 3.jpg
# 35.txt
# 39.txt
# 18.txt
# 38.txt
# 114.txt
# 36.txt
# 10.jpg
# 66.txt
# 24.txt
# 37.jpg
# 96.jpg
# 28.jpg
# 89.jpg
# 29.txt
# 98.txt
# 126.txt
# 21.txt
# 138.jpg
# 75.txt
# 128.txt
# 76.jpg
# 15.txt
# 109.txt
# 13.jpg
# 9.jpg
# 43.txt
# 110.txt
# 116.txt
# 24.jpg
# 137.txt
# 77.txt
# 30.jpg
# 116.jpg
# 107.jpg
# 21.jpg
# 49.txt
# 30.txt
# 54.txt
# 64.txt
# 95.txt
# 140.jpg
# 78.txt
# 16.txt
# 33.jpg
# 99.jpg
# 79.txt
# 141.txt
# ...
